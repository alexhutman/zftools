# %%
# This cell functions only because we have paid for CoCalc; unpaid accounts are not
# able to access external resources via the Internet

URL='https://raw.githubusercontent.com/jephianlin/mr_JG/master/zero_forcing_wavefront.pyx'

# %%
load(URL)
# Out:
# Compiling /home/user/.sage/temp/project-96f2cdd3-7b68-4107-a9fe-b71c35b63777/4017/tmp_pQROL_.pyx...
# warning: _home_user__sage_temp_project_96f2cdd3_7b68_4107_a9fe_b71c35b63777_4017_tmp_pQROL__pyx_0.pyx:110:18: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: _home_user__sage_temp_project_96f2cdd3_7b68_4107_a9fe_b71c35b63777_4017_tmp_pQROL__pyx_0.pyx:110:32: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: _home_user__sage_temp_project_96f2cdd3_7b68_4107_a9fe_b71c35b63777_4017_tmp_pQROL__pyx_0.pyx:110:47: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: _home_user__sage_temp_project_96f2cdd3_7b68_4107_a9fe_b71c35b63777_4017_tmp_pQROL__pyx_0.pyx:110:73: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# /ext/sage/sage-8.1/local/lib/python2.7/site-packages/sage/repl/load.py:251: DeprecationWarning: the file "stdsage.pxi" is deprecated, cimport the functions that you need
# See http://trac.sagemath.org/23855 for details.
#   exec(load_cython(fpath), globals)
# /ext/sage/sage-8.1/local/lib/python2.7/site-packages/sage/repl/load.py:251: DeprecationWarning: the file "cdefs.pxi" is deprecated, cimport the functions that you need
# See http://trac.sagemath.org/23855 for details.
#   exec(load_cython(fpath), globals)

# %%
# Set up a test graph H and display it if possible
H = graphs.MycielskiGraph(4)
#H = graphs.RobertsonGraph()
#H = graphs.CoxeterGraph()
#H = graphs.ClebschGraph()
#H = graphs.BrinkmannGraph()
#H = graphs.HeawoodGraph()
H.show()

# %% [markdown]
# #### %prun output = zero_forcing_set_wavefront(H)
# print "\nThis graph has", H.num_verts(), "vertices"
# print "Longest shortest path possible:", H.diameter()
# print output
